# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("netflix_titles.csv")

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df["type"].value_counts()
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
df["type"].value_counts().plot(kind="pie",figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='type'>

# %%
ratio= df["type"].value_counts()[0]/ df["type"].value_counts()[1]

# %%
ratio
# Out:
# 2.2911061285500747

# %% [markdown]
# # There are almost 3x more "Movies" than "Shows" on Netflix

# %%
directorr=df.groupby(["director"]).size().reset_index()
directorr
# Out:
#                  director  0
# 0             A. L. Vijay  2
# 1            A. Raajdheep  1
# 2               A. Salaam  1
# 3         A.R. Murugadoss  2
# 4         Aadish Keluskar  1
# ...                   ... ..
# 4523          Çagan Irmak  1
# 4524     Ísold Uggadóttir  1
# 4525  Óskar Thór Axelsson  1
# 4526     Ömer Faruk Sorak  2
# 4527         Şenol Sönmez  2
#
# [4528 rows x 2 columns]

# %%
directorr[directorr[0]==9]
# Out:
#          director  0
# 973  David Dhawan  9

# %%
df[df.director=="David Dhawan"]
# Out:
#      show_id   type                              title      director  \
# 205     s206  Movie  Kyo Kii... Main Jhuth Nahin Bolta  David Dhawan
# 2270   s2271  Movie                    Chashme Baddoor  David Dhawan
# 5009   s5010  Movie                           Judwaa 2  David Dhawan
# 6440   s6441  Movie                     Chal Mere Bhai  David Dhawan
# 6449   s6450  Movie                    Chashme Buddoor  David Dhawan
# 6936   s6937  Movie               Haseena Maan Jaayegi  David Dhawan
# 7144   s7145  Movie                             Judwaa  David Dhawan
# 7386   s7387  Movie              Maine Pyaar Kyun Kiya  David Dhawan
# 7524   s7525  Movie               Mujhse Shaadi Karogi  David Dhawan
#
#                                                    cast country  \
# 205   Govinda, Sushmita Sen, Rambha, Anupam Kher, Sa...   India
# 2270  Rishi Kapoor, Ali Zafar, Taapsee Pannu, Siddha...   India
# 5009  Varun Dhawan, Jacqueline Fernandez, Tapsee Pan...   India
# ...

# %%
directorr[directorr[0]==19]
# Out:
#            director   0
# 3392  Rajiv Chilaka  19

# %%
df[df.director=="Rajiv Chilaka"]
# Out:
#      show_id   type                                              title  \
# 406     s407  Movie                       Chhota Bheem - Neeli Pahaadi
# 407     s408  Movie                              Chhota Bheem & Ganesh
# 408     s409  Movie                 Chhota Bheem & Krishna: Mayanagari
# 409     s410  Movie  Chhota Bheem & Krishna: Pataliputra- City of t...
# 410     s411  Movie                 Chhota Bheem And The Broken Amulet
# 411     s412  Movie             Chhota Bheem And The Crown of Valhalla
# 412     s413  Movie               Chhota Bheem and the Incan Adventure
# 413     s414  Movie                Chhota Bheem and The ShiNobi Secret
# 414     s415  Movie                           Chhota Bheem Aur Hanuman
# 415     s416  Movie                           Chhota Bheem aur Krishna
# 416     s417  Movie                Chhota Bheem aur Krishna vs Zimbara
# 419     s420  Movie                      Chhota Bheem: Bheem vs Aliens
# ...

# %%
directorr.rename(columns={0:"Number of movies"},inplace=True)

# %%
director_df= directorr.groupby(["Number of movies"]).size()

# %%
director_df
# Out:
# Number of movies
# 1     3661
# 2      518
# 3      189
# 4       68
# 5       39
# 6       18
# 7       12
# 8       11
# 9        1
# 10       1
# 11       1
# 12       3
# 13       1
# 14       1
# 16       2
# 18       1
# 19       1
# dtype: int64

# %%
director_df.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Majority of the directors made single Movie or TV Show on Netflix

# %%
directorandtype=df.groupby(["director","type"]).size().reset_index()
directorandtype
directorandtype.rename(columns={0:"count"})
# Out:
#                  director   type  count
# 0             A. L. Vijay  Movie      2
# 1            A. Raajdheep  Movie      1
# 2               A. Salaam  Movie      1
# 3         A.R. Murugadoss  Movie      2
# 4         Aadish Keluskar  Movie      1
# ...                   ...    ...    ...
# 4571          Çagan Irmak  Movie      1
# 4572     Ísold Uggadóttir  Movie      1
# 4573  Óskar Thór Axelsson  Movie      1
# 4574     Ömer Faruk Sorak  Movie      2
# 4575         Şenol Sönmez  Movie      2
#
# [4576 rows x 3 columns]

# %%
directorofmovies= directorandtype[directorandtype["type"]=="Movie"]
directorofmovies
# Out:
#                  director   type  0
# 0             A. L. Vijay  Movie  2
# 1            A. Raajdheep  Movie  1
# 2               A. Salaam  Movie  1
# 3         A.R. Murugadoss  Movie  2
# 4         Aadish Keluskar  Movie  1
# ...                   ...    ... ..
# 4571          Çagan Irmak  Movie  1
# 4572     Ísold Uggadóttir  Movie  1
# 4573  Óskar Thór Axelsson  Movie  1
# 4574     Ömer Faruk Sorak  Movie  2
# 4575         Şenol Sönmez  Movie  2
#
# [4354 rows x 3 columns]

# %%
directorofmovies.drop(["type"],axis="columns")
# Out:
#                  director  0
# 0             A. L. Vijay  2
# 1            A. Raajdheep  1
# 2               A. Salaam  1
# 3         A.R. Murugadoss  2
# 4         Aadish Keluskar  1
# ...                   ... ..
# 4571          Çagan Irmak  1
# 4572     Ísold Uggadóttir  1
# 4573  Óskar Thór Axelsson  1
# 4574     Ömer Faruk Sorak  2
# 4575         Şenol Sönmez  2
#
# [4354 rows x 2 columns]

# %%
directorofmovies[0].nunique()
# Out:
# 18

# %%
directorofmovies.groupby(0).size()
# Out:
# 0
# 1     3521
# 2      496
# 3      182
# 4       65
# 5       37
# 6       18
# 7       14
# 8        9
# 9        1
# 10       1
# 11       1
# 12       3
# 13       1
# 14       1
# 15       1
# 16       1
# 18       1
# 19       1
# dtype: int64

# %% [markdown]
# # Majority of the directors directed a single movie througout, there is still a high number of directors who directed 2 to 3 movies. There are also some directors who made 9-19 movies too

# %%
directorofshows= directorandtype[directorandtype["type"]=="TV Show"]
directorofshows.drop(["type"],axis="columns")
# Out:
#                                   director  0
# 70               Adrien Lagier, Ousmane Ly  1
# 71                  Adrián García Bogliano  1
# 79                                Ah Loong  1
# 92                          Ahmet Katıksız  1
# 117                          Alain Brunard  1
# ...                                    ... ..
# 4395                   Vijay S. Bhanushali  1
# 4403  Vikramaditya Motwane, Anurag Kashyap  1
# 4488                        Wouter Bouvijn  1
# 4508                         Yasuhiro Irie  1
# 4555                          Ziad Doueiri  1
#
# [222 rows x 2 columns]

# %%
count_of_shows_per_director=directorofshows.groupby(0).size()
count_of_shows_per_director
# Out:
# 0
# 1    215
# 2      6
# 3      1
# dtype: int64

# %% [markdown]
# # Most of the directors(215) directed 1 TV Show throughtout, only 6 directors made 2 Shows and only 1 made 3 Shows.

# %%
df.release_year.nunique()
# Out:
# 74

# %%
year=df.groupby("release_year").size().reset_index()

# %%
year.rename(columns={0:"Number of releases"},inplace=True)

# %%
year
# Out:
#     release_year  Number of releases
# 0           1925                   1
# 1           1942                   2
# 2           1943                   3
# 3           1944                   3
# 4           1945                   4
# ..           ...                 ...
# 69          2017                1032
# 70          2018                1147
# 71          2019                1030
# 72          2020                 953
# 73          2021                 592
#
# [74 rows x 2 columns]

# %%
year.hist()
# Out:
# array([[<AxesSubplot:title={'center':'release_year'}>,
#         <AxesSubplot:title={'center':'Number of releases'}>]],
#       dtype=object)

# %% [markdown]
# To check latest no of releases

# %%
year[year.release_year>2015]
# Out:
#     release_year  Number of releases
# 68          2016                 902
# 69          2017                1032
# 70          2018                1147
# 71          2019                1030
# 72          2020                 953
# 73          2021                 592

# %%
year[year["Number of releases"]== (year["Number of releases"].max())]
# Out:
#     release_year  Number of releases
# 70          2018                1147

# %%
df[df["release_year"]==2018].groupby("type").size()
# Out:
# type
# Movie      767
# TV Show    380
# dtype: int64

# %% [markdown]
# # Netflix RELEASED the most in 2018 i.e 1147 releases including 767 Movies and 380 Shows

# %%
yeartemp= year.drop(70)

# %%
yeartemp.max()
# Out:
# release_year          2021
# Number of releases    1032
# dtype: int64

# %%
yeartemp[yeartemp["Number of releases"]==1032]
# Out:
#     release_year  Number of releases
# 69          2017                1032

# %%
df[df.release_year==2017].groupby("type").size()
# Out:
# type
# Movie      767
# TV Show    265
# dtype: int64

# %% [markdown]
# # SECOND MOST RELEASES were in 2017 with 1032 releases with 767 movies and 265 TV shows

# %%
yeartemp= year.drop([70,69])

# %%
yeartemp
# Out:
#     release_year  Number of releases
# 0           1925                   1
# 1           1942                   2
# 2           1943                   3
# 3           1944                   3
# 4           1945                   4
# ..           ...                 ...
# 67          2015                 560
# 68          2016                 902
# 71          2019                1030
# 72          2020                 953
# 73          2021                 592
#
# [72 rows x 2 columns]

# %%
yeartemp.max()
# Out:
# release_year          2021
# Number of releases    1030
# dtype: int64

# %%
year[year["Number of releases"]==1030]
# Out:
#     release_year  Number of releases
# 71          2019                1030

# %%
df[df["release_year"]==2019].groupby("type").size()
# Out:
# type
# Movie      633
# TV Show    397
# dtype: int64

# %% [markdown]
# # The third most releases were in the year 2019 with 1030 releases including 633 Movies and 397 TV Shows

# %%
df.groupby("country").size()
# Out:
# country
# , France, Algeria                                       1
# , South Korea                                           1
# Argentina                                              56
# Argentina, Brazil, France, Poland, Germany, Denmark     1
# Argentina, Chile                                        2
#                                                        ..
# Venezuela                                               1
# Venezuela, Colombia                                     1
# Vietnam                                                 7
# West Germany                                            1
# Zimbabwe                                                1
# Length: 748, dtype: int64

# %%
df_exploded= df.copy()

# %%
df_exploded["country"]= df["country"].str.split(",")
df_exploded
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast          country  \
# 0                                                   NaN  [United States]
# ...

# %%
df_exploded=df_exploded.explode("country")

# %%
df_exploded["country"].nunique()
# Out:
# 197

# %%
df_exploded=df_exploded.groupby("country").size().reset_index().rename(columns={0:"Number of releases"}).sort_values("Number of releases")

# %%
df_exploded
# Out:
#             country  Number of releases
# 196        Zimbabwe                   1
# 137       Guatemala                   1
# 32         Ethiopia                   1
# 136          Greece                   1
# 36            Ghana                   1
# ..              ...                 ...
# 122          Canada                 271
# 106   United States                 479
# 190  United Kingdom                 628
# 141           India                1008
# 191   United States                3211
#
# [197 rows x 2 columns]

# %%
df_country= df_exploded.tail(3)

# %%
df_country
# Out:
#             country  Number of releases
# 190  United Kingdom                 628
# 141           India                1008
# 191   United States                3211

# %%
df_exploded.tail(15).plot(kind="bar",x="country")
# Out:
# <AxesSubplot:xlabel='country'>

# %% [markdown]
# # United King stands first for its number of releases with 3211 releases, India stands second with 1008 releases and then United Kingdom stands third with 628 releases

# %%
df_UK= df.copy()
df_UK["country"]= df_UK["country"].str.split(",")
df_UK=df_UK.explode("country")

# %%
df_UK=df_UK[df_UK["country"]=="United States"]

# %%
df_UK=df_UK.groupby("release_year").size().reset_index()

# %%
df_UK
# Out:
#     release_year    0
# 0           1942    2
# 1           1943    3
# 2           1944    3
# 3           1945    4
# 4           1946    2
# ..           ...  ...
# 64          2017  381
# 65          2018  386
# 66          2019  382
# 67          2020  352
# 68          2021  153
#
# [69 rows x 2 columns]

# %%
df_UK['release_year'] = df_UK["release_year"].astype('category')

# %%
df_UK.tail(14).plot(kind="bar",x="release_year")
# Out:
# <AxesSubplot:xlabel='release_year'>

# %% [markdown]
# # This graph shows the releases from United Kingdom over the years

# %%
df.rating.unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
ratings= df.groupby("rating").size().reset_index().sort_values(0)

# %%
ratings
# Out:
#       rating     0
# 0     66 min     1
# 1     74 min     1
# 2     84 min     1
# 4      NC-17     3
# 16        UR     3
# 15  TV-Y7-FV     6
# 3          G    41
# 5         NR    80
# 10      TV-G   220
# 6         PG   287
# 13      TV-Y   307
# 14     TV-Y7   334
# 7      PG-13   490
# 8          R   799
# 12     TV-PG   863
# 9      TV-14  2160
# 11     TV-MA  3207

# %%
ratings.tail(5).plot(kind="bar",x="rating")
# Out:
# <AxesSubplot:xlabel='rating'>

# %% [markdown]
# # Most of the releases are rated TV-MA, second most are rated TV-14 and third, TV-PG

# %%
listed=df.copy()

# %%
listed["listed_in"]=listed["listed_in"].str.split(",")

# %%
listed= listed.explode("listed_in")

# %%
listed
# Out:
#      show_id     type                 title         director  \
# 0         s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show         Blood & Water              NaN
# 1         s2  TV Show         Blood & Water              NaN
# 1         s2  TV Show         Blood & Water              NaN
# 2         s3  TV Show             Ganglands  Julien Leclercq
# ...      ...      ...                   ...              ...
# 8805   s8806    Movie                  Zoom     Peter Hewitt
# 8805   s8806    Movie                  Zoom     Peter Hewitt
# 8806   s8807    Movie                Zubaan      Mozez Singh
# 8806   s8807    Movie                Zubaan      Mozez Singh
# 8806   s8807    Movie                Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
listed["listed_in"].unique()
# Out:
# array(['Documentaries', 'International TV Shows', ' TV Dramas',
#        ' TV Mysteries', 'Crime TV Shows', ' International TV Shows',
#        ' TV Action & Adventure', 'Docuseries', ' Reality TV',
#        ' Romantic TV Shows', ' TV Comedies', 'TV Dramas', ' TV Horror',
#        'Children & Family Movies', 'Dramas', ' Independent Movies',
#        ' International Movies', 'British TV Shows', 'Comedies', ' Dramas',
#        ' Docuseries', ' Comedies', ' Crime TV Shows', 'TV Comedies',
#        ' Spanish-Language TV Shows', 'Thrillers', ' Romantic Movies',
#        ' Music & Musicals', 'Horror Movies', ' Sci-Fi & Fantasy',
#        ' TV Thrillers', "Kids' TV", ' Thrillers', 'Action & Adventure',
#        ' TV Sci-Fi & Fantasy', ' Classic Movies', ' Horror Movies',
#        ' Anime Features', 'Reality TV', ' Sports Movies', 'Anime Series',
#        " Kids' TV", 'International Movies', ' Korean TV Shows',
#        'Sci-Fi & Fantasy', ' Science & Nature TV', ' Teen TV Shows',
# ...

# %%
lis["listed_in2"]= np.where(lis["listed_in"].str.startswith(" ")==False, lis["listed_in"], lis["listed_in"].str[1:])
# Out:
# C:\Users\www\AppData\Local\Temp/ipykernel_18052/3511454309.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lis["listed_in2"]= np.where(lis["listed_in"].str.startswith(" ")==False, lis["listed_in"], lis["listed_in"].str[1:])

# %%
lis
# Out:
#      show_id     type                  title         director  \
# 1         s2  TV Show          Blood & Water              NaN
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# ...      ...      ...                    ...              ...
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
lis["listed_in2"].unique()
# Out:
# array(['TV Dramas', 'TV Mysteries', 'International TV Shows',
#        'TV Action & Adventure', 'Reality TV', 'Romantic TV Shows',
#        'TV Comedies', 'TV Horror', 'Independent Movies',
#        'International Movies', 'Dramas', 'Docuseries', 'Comedies',
#        'Crime TV Shows', 'Spanish-Language TV Shows', 'Romantic Movies',
#        'Music & Musicals', 'Sci-Fi & Fantasy', 'TV Thrillers',
#        'Thrillers', 'TV Sci-Fi & Fantasy', 'Classic Movies',
#        'Horror Movies', 'Anime Features', 'Sports Movies', "Kids' TV",
#        'Korean TV Shows', 'Science & Nature TV', 'Teen TV Shows',
#        'Cult Movies', 'Children & Family Movies', 'Faith & Spirituality',
#        'LGBTQ Movies', 'Stand-Up Comedy & Talk Shows', 'Documentaries',
#        'Classic & Cult TV', 'Stand-Up Comedy'], dtype=object)

# %%
lis["listed_in2"].nunique()
# Out:
# 37

# %%
liss= lis.groupby("listed_in2").size().sort_values()

# %%
liss.plot(kind="bar",figsize=(8,8))
# Out:
# <AxesSubplot:xlabel='listed_in2'>

# %%
liss.tail(5).plot(kind="bar",figsize=(7,7))
# Out:
# <AxesSubplot:xlabel='listed_in2'>

# %% [markdown]
# # Top releases are "International Movies", followed by "Dramas", "Independent Movies", "TV Dramas" and then"Romantic Movies"

# %%
df.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
# ...

# %%
month=df.copy()

# %%
month["date_added"] = month["date_added"].str[:3]

# %%
month
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
months= month.groupby("date_added").size().sort_values()

# %%
months.tail(10).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='date_added'>

# %% [markdown]
# # Netflix releases the most in the month of July, followed by December , September and then April
